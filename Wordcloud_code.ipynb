# %% [markdown]
# <a href="https://colab.research.google.com/github/arenamichela/-CE880_Lab_Work/blob/main/Wordcloud_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# **Jupiter Notebook:** *Wordcloud code*
#
# **Author:** *Michela Arena*
#
# **Date**: *October 3, 2024*
#
# ---

# %% [markdown]
# Script to generate a word cloud from a given text input, with options for:
# - Removing stopwords (from multiple libraries like NLTK, SpaCy, and Gensim)
# - Filtering out words based on minimum frequency
# - Customizing the word cloud's appearance (shape, colors, etc.)
# - Saving the resulting word cloud as an image file

# %% [markdown]
# # **Importing Required Libraries**

# %%
pip install pandas openpyxl

# %%
# Import necessary libraries for word processing and visualization
import pandas as pd  # For handling data in DataFrame format
from collections import Counter  # For counting word frequencies
from nltk.corpus import stopwords  # For removing common stopwords
from wordcloud import WordCloud  # For generating word clouds
import matplotlib.pyplot as plt  # For visualizing the word cloud
import string  # For handling punctuation
import nltk  # For downloading stopwords if necessary
from collections import Counter
import numpy as np
from PIL import Image

# %% [markdown]
# # **Counting Word Frequencies**

# %%
import pandas as pd
from collections import Counter

# Example input: You can replace this with your actual text or list of words
# Each word in this text will be counted.
text = """
[INSERT YOUR OPEN ENDED RESPONSES HERE]
"""

# Step 1: Split the text into words, remove punctuation, and convert to lowercase
words = text.lower().replace('.', '').replace(',', '').split()

# Step 2: Use Counter to count the frequency of each word
word_count = Counter(words)

# Step 3: Convert the dictionary into a DataFrame
df = pd.DataFrame(word_count.items(), columns=['Word', 'Count'])

# Step 4: Save the DataFrame to an Excel file
excel_filename = 'word_count.xlsx'
df.to_excel(excel_filename, index=False)

# Display the DataFrame for reference in Jupyter Notebook
df
# Out:
#         Word  Count
# 0       this      3
# 1         is      2
# 2         an      1
# 3    example      1
# 4         of      1
# 5          a      1
# 6       text      3
# 7      meant      1
# 8         to      1
# 9         be      2
# 10      used      1
# 11       for      1
# 12  counting      1
# 13      each      2
# 14      word      2
# 15        in      1
# 16      will      1
# 17   counted      1

# %% [markdown]
# # **EXAMPLE- RUN THIS CELL ONLY TO TRY THE CODE**

# %%
import pandas as pd
from collections import Counter
text = """
Due to the complexity of the population, crime may increase
lives on the seafront, sees groups of young people leaving clubs at night, drunk people making noise, parking wildly, damaging cars and rubbish bins and other things
Rents and cost of living.
the growth in the number of tourists does not correspond to the growth of the infrastructure and the disadvantages for residents increase
some tourists complain about our attitudes
accommodation
I love few people and little chaos.
Even though tourism increases, it does not generate only precarious jobs.
It should be further developed for greater economic development.
crime increases - nightclubs increase alcoholism problems
significantly increase the number of inhabitants in the area
increase in the cost of real estate
increase in rental costs
chaos and traffic
Lack of quality services
Lack of facilities and services
Lack of accommodation facilities
That increases attendance without improving traffic
That there is too much speculation
that there is overcrowding
THAT BECOMES VERY CRITICAL TO MOVE, LACK OF INFRASTRUCTURE
That they can do damage
that only a certain type of tourism or one linked to gastronomy is valorised instead of the important archaeological heritage or landscape aspect
THAT INFRASTRUCTURES ARE BUILT WHICH COULD DAMAGE THE ENVIRONMENT
there should be a cruise port planned, there will be a traffic problem
there would be a need for more security and health services. from 5000 we go to 50000 people
confusion, pollution, etc.
against the construction of the port for cruise ships
Create reception infrastructures that allow both tourists and citizens to enjoy the beauty and offers of the municipality: defined cycle paths, intensified beach/terminal vehicle service, creation of car parks -
Create more infrastructure to allow tourists not to move elsewhere when disembarking by plane
I BELIEVE THERE IS TOO MUCH LOW QUALITY TOURISM
crime
crime and excessive traffic
crime, worsens environmental dirtiness, too much traffic on transport
It needs to be cleaner, more can be done, the cars run too fast
They need to add more public transportation
Discomfort in daily life
Unemployment
Destruction of the ecosystem and increase in prices
Destruction of the ecosystem and increase in prices
It becomes impossible to live on the streets on weekends and create outdoor parking spaces
It should be managed better. It offers no other tourist interests other than the beach
it is difficult to pass through for tourism-related traffic
It is difficult to find a house to live in. Prices are too high
it favors work and the economy, but when there are too many it becomes crowded
Fiumicino is not a tourist area
frustration with roads and infrastructure and traffic
People who don't care about the environment
Management not good reception
there is little money in circulation
he is afraid that the level of security will decrease
he's afraid that the port will ruin the city
The means of transport are inefficient and we locals are penalized as we have difficulty getting around the city as we are forced to pay very high prices to go to work by taxi! And what's more, rents are sky-high! And this is a big disadvantage for residents
The few means of transport and those that exist do not work well
The problems of tourism are only to the benefit of a few and not of the entire population, too much dirt, traffic and chaos and the municipality does very little to guarantee cleanliness and control of car parks, absence of police forces on the streets and the consequence impacts on residents.
Transport
tourists do not respect the environment, damaging it with their waste that they leave everywhere
Holidaymakers leave their waste on the streets and on the beaches
Chaos and fewer jobs
The most crowded center and few dedicated infrastructures
The social and environmental degradation that ensues
the fact that a network of services is not created starting from healthcare ones to also meet the needs of tourists, as well as the local infrastructures which are already too lacking and congested.
the large flow of tourists damages the market, exponentially raises rental prices
the new port of Fiumicino
parking in the summer
the cruise port
the port for cruise ships transit only
the noise at night from the pubs near the houses
traffic
The traffic
traffic
Tourism is little
Tourism is good, but the place needs to improve for year-round residents
The tourist saves money and brings money
the tourist who is not adequately informed produces disorder from an environmental point of view above all
immigration
Immigration
In some regions, concerns about tourism are evident. Competition from other destinations, climate change and economic fluctuations put the local tourism industry at risk. It is necessary to find innovative solutions to attract visitors and preserve natural and cultural beauty.
In the summer there is a significant flow of tourists. The infrastructure should be improved, making the beaches cleaner and the bathing establishments more inviting
in particular when the flow of tourists increases, therefore increase public transport and services
Encourage tourism and environmental sustainability
infrastructure, everything closed, things should be done for everyone
invest more to improve infrastructure
The harmony between man and nature and other aspects.
The high entry of people could lead to the entry of wrong people
Immigration is very exaggerated, I hope that something can be done especially for the illegal immigrants who cause fear on the streets of Rome
Garbage and wild parking lots
The pollution of the sea
the `quality', the rudeness and ignorance of some tourists,
the ability to know how to coherently manage these types of policies in all aspects, including the environment. Make sure it is not harmful
the clandestine nature of immigration
Crime
Environmental care
delinquency
The crowd will be very mixed, which could lead to an increase in the crime rate.
The frustration of the constant overhead traffic and the worry of driving away tourism due to this problem
The lack of clean beaches and dirty streets
My area is not very well known
cleaning
The quality of the water. We don't have a clean sea
Rapid population growth could lead to an increase in crime
the type of tourism that arrives
the road conditions worry me
the liveability of the community
large cruise ships cause pollution and disruption of the territory
the infrastructures
The infrastructures are inadequate, politics shows no real interest in environmental protection
the infrastructures. the few roads are already very busy as it is
the concerns are the same as the answers, related to security and related to services
Curse of the tourists
There is a lack of transport and road controls and citizens cannot leave because they are stuck
there is a lack of infrastructure, roads...
infrastructure is lacking
there is a lack of infrastructure (accommodation and diversion areas) to welcome tourists
Lack of houses rented out as the majority are B&Bs with increased rents, increased cost of living, increased cost of selling houses
lack of infrastructure
I am concerned about the lack of respect for the environment, but I believe that with the right actions we can reconcile tourism with the environmental issue
improve connections to the capital
mobility, does not see much public transport. there are tourists who travel around with trolleys. public network not convenient
many services are more available to tourism than to the local community
No worries whatsoever
"""

# Step 1: Split the text into words, remove punctuation, and convert to lowercase
words = text.lower().replace('.', '').replace(',', '').split()

# Step 2: Use Counter to count the frequency of each word
word_count = Counter(words)

# Step 3: Convert the dictionary into a DataFrame
df = pd.DataFrame(word_count.items(), columns=['Word', 'Count'])

# Step 4: Save the DataFrame to an Excel file
excel_filename = 'word_count.xlsx'
df.to_excel(excel_filename, index=False)

# Display the DataFrame for reference in Jupyter Notebook
df
# Out:
#            Word  Count
# 0           due      2
# 1            to     36
# 2           the    103
# 3    complexity      1
# 4            of     56
# ..          ...    ...
# 451    trolleys      1
# 452  convenient      1
# 453   available      1
# 454     worries      1
# 455  whatsoever      1
#
# [456 rows x 2 columns]

# %% [markdown]
# # **Filter the Data**

# %%
import nltk
from gensim.parsing.preprocessing import STOPWORDS as gensim_stopwords
import spacy
nlp = spacy.load('en_core_web_sm')

# Download the NLTK stopwords if not already available. This ensures that
# the script can run without any issues even if it's executed on a fresh system.
nltk.download('stopwords')

# Define stopwords in English from NLTK and add any custom words specific to your needs.
# Additional stopwords can be customized based on your use case (e.g., project-specific words).
stop_words_nltk = set(stopwords.words('english'))
stop_words_spacy = nlp.Defaults.stop_words
stop_words_gensim = gensim_stopwords

# Combine all stopwords into one set
combined_stopwords = stop_words_nltk.union(stop_words_spacy).union(stop_words_gensim)

# Additional stopwords that are not part of NLTK but may be useful to filter out
additional_stopwords = {"due", "example", "specific_word"}  # Add your custom stopwords here

# Combine all stopwords into a single set
all_stopwords = stop_words_nltk.union(additional_stopwords)


# Step 1: Split the text into words, remove punctuation, convert to lowercase, and filter out stopwords
words = text.lower().split()
words = [word.strip(string.punctuation) for word in words if word not in all_stopwords and word not in string.punctuation]

# Step 2: Use Counter to count the frequency of each word
word_count = Counter(words)

# Step 3: Convert the dictionary into a DataFrame
df = pd.DataFrame(word_count.items(), columns=['Word', 'Count'])

# Step 4: Remove words that were counted less than 4 times
# Filter out words that appear fewer than 4 times to remove noise from the data.
# This helps in creating a more meaningful word cloud.
df_filtered = df[df['Count'] >= 4] # You can change the threshold based on preference

# Step 5: Save the filtered DataFrame to an Excel file
# Convert the word count dictionary to a DataFrame and save it to an Excel file
excel_filename = 'wordcount_output.xlsx' # Specify the file name
df_filtered.to_excel(excel_filename, index=False)

# Display the filtered DataFrame for reference
df_filtered
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                 Word  Count
# 2              crime      8
# 4           increase     11
# 10            people      7
# 17           parking      4
# 25              cost      4
# 29          tourists     13
# 31    infrastructure     11
# 33         residents      4
# 38            little      4
# 39             chaos      4
# 42           tourism     13
# 43         increases      4
# 61           traffic     12
# 62              lack     11
# 63           quality      4
# 64          services      7
# 69              much      5
# 88   infrastructures      7
# 90             could      4
# 91       environment      5
# 92            cruise      5
# 93              port      6
# 133    environmental      7
# 135        transport      7
# 142           public      4
# 150           prices      5
# 153          streets      5
# 159          tourist      4
# ...

# %% [markdown]
# # **WordCloud Creation**

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# Step 3: Create a circular mask for the word cloud
x, y = np.ogrid[:800, :800]
mask = (x - 400) ** 2 + (y - 400) ** 2 > 400 ** 2  # Circle formula (x-h)^2 + (y-k)^2 = r^2
mask = 255 * mask.astype(int)  # Convert to the format required by WordCloud (0 or 255)

# Step 4: Create a WordCloud object
# Create a WordCloud object, specifying customizations like size, color scheme, and mask.
# You can modify the colormap to change the color scheme (e.g., 'rainbow', 'Dark2').
wordcloud = WordCloud(width=800, height=800, background_color='white', mask=mask, colormap='Dark2').generate_from_frequencies(word_count)

# Step 5: Plot the WordCloud
# The 'imshow' function displays the generated word cloud as an image.
plt.figure(figsize=(10, 10))  # Set the figure size for better visibility
plt.imshow(wordcloud, interpolation='bilinear')  # Render the word cloud with smooth edges
plt.axis('off')  # Turn off the axis since it's not needed for word clouds
plt.show()  # Display the word cloud on the screen


# Step 6: Save the word cloud image to a file
wordcloud_image_filename = 'wordcloud_output.png'  # Specify the filename for the word cloud image
wordcloud.to_file(wordcloud_image_filename)  # Save the image to the specified path

# %% [markdown]
# # **USE THE CODE HERE**

# %%
import pandas as pd
from collections import Counter

# Example input: You can replace this with your actual text or list of words
text = """
[INSERT YOUR OPEN ENDED RESPONSES HERE]
"""

# Step 1: Split the text into words, remove punctuation, and convert to lowercase
words = text.lower().replace('.', '').replace(',', '').split()

# Step 2: Use Counter to count the frequency of each word
word_count = Counter(words)

# Step 3: Convert the dictionary into a DataFrame
df = pd.DataFrame(word_count.items(), columns=['Word', 'Count'])

# Step 4: Save the DataFrame to an Excel file
excel_filename = 'word_count.xlsx'
df.to_excel(excel_filename, index=False)

# Display the DataFrame for reference in Jupyter Notebook
df

# %%
import pandas as pd
from collections import Counter
from nltk.corpus import stopwords
import string
import nltk

# Download the stopwords if not already downloaded
nltk.download('stopwords')

# Define stopwords in English and any other custom words to exclude
stop_words = set(stopwords.words('english'))
additional_stopwords = {'insert', 'open', 'ended', 'responses', 'here'}  # Add your own custom words here if needed

# Combine the stopwords with the additional words to remove
all_stopwords = stop_words.union(additional_stopwords)

# Step 1: Split the text into words, remove punctuation, convert to lowercase, and filter out stopwords
words = text.lower().split()
words = [word.strip(string.punctuation) for word in words if word not in all_stopwords and word not in string.punctuation]

# Step 2: Use Counter to count the frequency of each word
word_count = Counter(words)

# Step 3: Convert the dictionary into a DataFrame
df = pd.DataFrame(word_count.items(), columns=['Word', 'Count'])

# Step 4: Save the DataFrame to an Excel file
excel_filename = 'word_count_filtered.xlsx'
df.to_excel(excel_filename, index=False)

# Display the DataFrame for reference in Jupyter Notebook
df

# %% [markdown]
# This script is designed to automate the process of creating a word cloud from a given text input.
# It allows for filtering based on frequency and provides customizations for word cloud appearance.
# Future customizations may include:
# - Using different masks (shapes) for the word cloud
# - Allowing for additional input formats (e.g., CSV files, direct text input from a user)
